# %% [markdown]
# # Building a Task Oriented Bot

# %% [markdown]
# For this particular Machine Learning project I wanted to combine my interest as an aspiring Product Manager with my current work experience as a collections supervisor with the knowledge accumulated in the Machine learning module.
# Building a chatbot that is able to provide answers related to invoicing and payment questions seemed for me the best way to achieve this.

# %% [markdown]
# ### I started with putting the pseudo code together - how the interaction would look like

# %% [markdown]
# Pseudo code chatbot
# 1. User starts the conversation
# 2. Chatbot has answers for a list of questions that can be asked on the topic of invoicing and payment options
# 3. Chatbot has a slight capacity for correctly picking the right answer even when there are minor spelling mistakes
# 4. Topics for which chatbot can provide answers: how to pay an invoice, where to find an invoice, how to change payment method, what to do when invoice is wrong.
# 5. Chatbot is also able to recognize when user asks to be transferred to human agent to continue the conversation
#
# Next steps:
# 1. Create the possibility for chatbot to initiate the conversation when user is logged on the page (proactivity)
# 2. Create the possibility for the chatbot to recognize correct invoice numbers + gather details + generate case number when extra work is needed by another dept
# 3. Create the possibility to have multiple interactions instead of just 1 to 1 question and answers.
# 4. Create the possibility of asking for feedback and registering the feedback on the helpfulness of the answer provided by the chatbot (After each question ask Was the answer helpful? If yes chatbot asks "Is there additional topics you need help with?" if yes continue with the loop. If no chatbot Thank you for reaching out to us, have a great day!. If No after Was the answer helpful? Chatbot says Sorry to hear that, let me put you in contact with an agent that can help you further)

# %% [markdown]
# ## Code used for this project is sourced from here
# https://data-flair.training/blogs/python-chatbot-project/
#
# https://dzone.com/articles/python-chatbot-project-build-your-first-python-pro
#
# https://www.datacamp.com/community/tutorials/building-a-chatbot-using-chatterbot

# %%
#pip install numpy==1.19.3

# %% [markdown]
# ## Importing the libraries necessary for the whole project

# %%
import numpy as np
from tensorflow import keras #Tensorflow and Keras are used for the training of the chatbot
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D, Activation, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
import random
import nltk
from nltk.stem import WordNetLemmatizer #https://www.geeksforgeeks.org/python-lemmatization-with-nltk/#:~:text=Lemmatization%20is%20the%20process%20of,similar%20meaning%20to%20one%20word. Lemmatization is the process of grouping together the different inflected forms of a word so they can be analysed as a single item. Lemmatization is similar to stemming but it brings context to the words. So it links words with similar meaning to one word.
lemmatizer = WordNetLemmatizer()
import json
import pickle #https://docs.python.org/3/library/pickle.html The pickle module implements binary protocols for serializing and de-serializing a Python object structure. “Pickling” is the process whereby a Python object hierarchy is converted into a byte stream, and “unpickling” is the inverse operation, whereby a byte stream (from a binary file or bytes-like object) is converted back into an object hierarchy. Pickling (and unpickling) is alternatively known as “serialization”, “marshalling,” 1 or “flattening”; however, to avoid confusion, the terms used here are “pickling” and “unpickling”.
import nltk
nltk.download('punkt') #https://www.kite.com/python/docs/nltk.punkt Punkt Sentence Tokenizer This tokenizer divides a text into a list of sentences, by using an unsupervised algorithm to build a model for abbreviation words, collocations, and words that start sentences. It must be trained on a large collection of plaintext in the target language before it can be used. The NLTK data package includes a pre-trained Punkt tokenizer for English.
import nltk
nltk.download('wordnet') #https://www.tutorialspoint.com/how-to-get-synonyms-antonyms-from-nltk-wordnet-in-python#:~:text=The%20WordNet%20is%20a%20part,then%20download%20the%20WordNet%20package. The WordNet is a part of Python's Natural Language Toolkit. It is a large word database of English Nouns, Adjectives, Adverbs and Verbs. These are grouped into some set of cognitive synonyms, which are called synsets.
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Merti\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Merti\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# #### Importing the "intents" file in which we create the potential questions from the user and potential answers from the chatbot, where we have the following structure

# %% [markdown]
# #tag - type of topic discussed
# #patterns - potential user input
# #responses - variation of possible chatbot responses which can be given based on the patterns

# %%
intents_file = open('intents.json').read()
intents = json.loads(intents_file)

# %% [markdown]
# In this first phase the potential questions from user (the patterns) are split, tokenized, linked to a tag (so there is a connection between the tag-topic and the pattern - user question). by printing documents we see this connection made between the tag and the pattern

# %%
words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)        
        #add documents in the corpus
        documents.append((word, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

print(documents)
# Out:
# [(['Hi'], 'greeting'), (['Hey'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hello'], 'greeting'), (['Hay'], 'greeting'), (['Good', 'morning'], 'greeting'), (['Good', 'day'], 'greeting'), (['Good', 'evening'], 'greeting'), (['Good', 'afternoon'], 'greeting'), (['Hiya'], 'greeting'), (['Bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['Have', 'a', 'nice', 'day'], 'goodbye'), (['Have', 'a', 'great', 'day'], 'goodbye'), (['See', 'ya'], 'goodbye'), (['Later'], 'goodbye'), (['Thanks'], 'thanks'), (['Thank', 'you'], 'thanks'), (['That', "'s", 'helpful'], 'thanks'), (['Thanks', 'for', 'the', 'help'], 'thanks'), (['Who', 'are', 'you', '?'], 'name'), (['What', 'are', 'you', '?'], 'name'), (['Who', 'am', 'I', 'talking', 'to', '?'], 'name'), (['what', 'is', 'your', 'name'], 'name'), (['what', 'should', 'I', 'call', 'you'], 'name'), (['whats', 'your', 'name', '?'], 'name'), (['Could', 'you', 'help', 'me', '?'], 'help'), (['give', 'me', 'a', 'hand', 'please'], 'help'), (['Can', 'you', 'help', '?'], 'help'), (['What', 'can', 'you', 'do', 'for', 'me', '?'], 'help'), (['I', 'need', 'support'], 'help'), (['I', 'need', 'help'], 'help'), (['support', 'me', 'please'], 'help'), (['help', 'me', 'please'], 'help'), (['help', 'me'], 'help'), (['I', 'have', 'an', 'outstanding', 'invoice', 'how', 'can', 'I', 'pay', 'it'], 'payinvoice'), (['I', 'have', 'an', 'overdue', 'invoice', 'how', 'can', 'I', 'pay', 'it'], 'payinvoice'), (['I', 'need', 'to', 'pay', 'my', 'overdue', 'invoice'], 'payinvoice'), (['I', 'need', 'to', 'pay', 'my', 'invoice'], 'payinvoice'), (['how', 'to', 'pay', 'my', 'invoice'], 'payinvoice'), (['I', 'want', 'to', 'pay', 'an', 'invoice'], 'payinvoice'), (['can', 'you', 'tell', 'me', 'how', 'to', 'pay', 'an', 'invoice'], 'payinvoice'), (['I', 'have', 'an', 'invoice', 'to', 'be', 'paid'], 'payinvoice'), (['I', 'have', 'to', 'pay', 'an', 'invoice'], 'payinvoice'), (['I', 'need', 'a', 'copy', 'of', 'my', 'invoice'], 'findinvoice'), (['I', 'want', 'a', 'copy', 'of', 'an', 'invoice'], 'findinvoice'), (['i', 'need', 'to', 'retrieve', 'an', 'invoice'], 'findinvoice'), (['i', 'want', 'to', 'download', 'an', 'invoice'], 'findinvoice'), (['i', 'want', 'to', 'access', 'an', 'invoice'], 'findinvoice'), (['can', 'I', 'obtain', 'a', 'copy', 'of', 'an', 'invoice'], 'findinvoice'), (['where', 'can', 'I', 'find', 'my', 'invoice'], 'findinvoice'), (['where', 'do', 'I', 'find', 'an', 'invoice'], 'findinvoice'), (['where', 'can', 'I', 'get', 'an', 'invoice'], 'findinvoice'), (['My', 'invoice', 'is', 'wrong'], 'wronginvoice'), (['My', 'invoice', 'is', 'wrong', ',', 'I', 'need', 'to', 'make', 'changes', 'before', 'I', 'can', 'pay'], 'wronginvoice'), (['invoice', 'is', 'not', 'correct'], 'wronginvoice'), (['the', 'invoice', 'is', 'incorrect'], 'wronginvoice'), (['can', 'i', 'get', 'the', 'invoice', 'corrected'], 'wronginvoice'), (['how', 'can', 'i', 'correct', 'my', 'invoice'], 'wronginvoice'), (['there', 'is', 'an', 'error', 'in', 'my', 'invoice', ',', 'how', 'can', 'I', 'correct', 'it'], 'wronginvoice'), (['how', 'to', 'amend', 'a', 'fault', 'in', 'the', 'invoice'], 'wronginvoice'), (['there', 'is', 'something', 'wrong', 'with', 'my', 'invoice', ',', 'how', 'can', 'I', 'get', 'it', 'corrected'], 'wronginvoice'), (['Invoice', 'has', 'wrong', 'amount'], 'wronginvoiceamount'), (['Wrong', 'amount'], 'wronginvoiceamount'), (['invoice', 'amount', 'is', 'not', 'correct'], 'wronginvoiceamount'), (['amount', 'is', 'wrong'], 'wronginvoiceamount'), (['amount', 'is', 'incorrect'], 'wronginvoiceamount'), (['charge', 'is', 'incorrect'], 'wronginvoiceamount'), (['invoice', 'shows', 'wrong', 'amount', ',', 'how', 'can', 'I', 'correct', 'it'], 'wronginvoiceamount'), (['how', 'to', 'amend', 'the', 'wrong', 'amount'], 'wronginvoiceamount'), (['amount', 'charged', 'is', 'wrong'], 'wronginvoiceamount'), (['amount', 'charged', 'is', 'not', 'correct'], 'wronginvoiceamount'), (['Invoice', 'has', 'wrong', 'details'], 'wronginvoi ...

# %% [markdown]
# 2 files words and classes are created based on the information from the lemmatization. the tags are turned into 13 classes. there are 112 unique lemmatized words based on the information

# %%
# lemmatize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 110 documents
# 13 classes ['changepayment', 'findinvoice', 'goodbye', 'greeting', 'help', 'human', 'name', 'payinvoice', 'thanks', 'wronginvoice', 'wronginvoiceamount', 'wronginvoicedetails', 'wronginvoiceduedate']
# 112 unique lemmatized words ["'s", 'a', 'access', 'afternoon', 'agent', 'am', 'amend', 'amount', 'an', 'anymore', 'anyone', 'are', 'available', 'be', 'before', 'being', 'billing', 'bye', 'call', 'can', 'change', 'charge', 'charged', 'contact', 'copy', 'correct', 'corrected', 'could', 'date', 'day', 'detail', 'different', 'do', 'dont', 'download', 'due', 'error', 'evening', 'fault', 'find', 'for', 'get', 'give', 'good', 'goodbye', 'great', 'ha', 'hand', 'have', 'hay', 'hello', 'help', 'helpful', 'hey', 'hi', 'hiya', 'how', 'human', 'i', 'in', 'incorrect', 'invoice', 'is', 'it', 'later', 'make', 'me', 'mentioned', 'method', 'morning', 'my', 'name', 'need', 'nice', 'not', 'obtain', 'of', 'on', 'outstanding', 'overdue', 'paid', 'pay', 'payment', 'person', 'please', 'retrieve', 'see', 'select', 'should', 'show', 'something', 'support', 'talk', 'talking', 'tell', 'thank', 'thanks', 'that', 'the', 'there', 'to', 'want', 'way', 'what', 'whats', 'where', 'who', 'with', 'wrong', 'ya', 'you', 'your']

# %% [markdown]
# In this step the training data is created with the bag of words method.

# %%
# create the training data
training = []
# create empty array for the output
output_empty = [0] * len(classes)
# training set, bag of words for every sentence
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    word_patterns = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    # create the bag of words array with 1, if word is found in current pattern
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
# shuffle the features and make numpy array
random.shuffle(training)
training = np.array(training)
# create training and testing lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data is created")
# Out:
# Training data is created
# C:\Users\Merti\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %% [markdown]
# Create the neural network model using the Sequential method. Sequential API is the easiest model to build and run in Keras. A sequential model allows us to create models layer by layer in a step by step fashion.

# %%
# deep neural network model
model = Sequential()
model.add(Dense(200, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compiling model. SGD with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#Training and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model is created")
# Out:
# Epoch 1/200
# 22/22 [==============================] - 0s 1ms/step - loss: 2.5460 - accuracy: 0.1000
# Epoch 2/200
# 22/22 [==============================] - 0s 2ms/step - loss: 2.3750 - accuracy: 0.2273
# Epoch 3/200
# 22/22 [==============================] - 0s 1ms/step - loss: 2.1545 - accuracy: 0.3636
# Epoch 4/200
# 22/22 [==============================] - 0s 1ms/step - loss: 1.8594 - accuracy: 0.4455
# Epoch 5/200
# 22/22 [==============================] - 0s 2ms/step - loss: 1.4895 - accuracy: 0.6000
# Epoch 6/200
# 22/22 [==============================] - 0s 2ms/step - loss: 1.2187 - accuracy: 0.6636
# Epoch 7/200
# 22/22 [==============================] - 0s 2ms/step - loss: 1.1274 - accuracy: 0.7000
# Epoch 8/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.9114 - accuracy: 0.7636
# Epoch 9/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.8144 - accuracy: 0.7455
# Epoch 10/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.7650 - accuracy: 0.7545
# Epoch 11/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.6943 - accuracy: 0.8091
# Epoch 12/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.5440 - accuracy: 0.8818
# Epoch 13/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4760 - accuracy: 0.8909
# Epoch 14/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4243 - accuracy: 0.8636
# Epoch 15/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3226 - accuracy: 0.9182
# Epoch 16/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.2788 - accuracy: 0.9273
# Epoch 17/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.2796 - accuracy: 0.9455
# Epoch 18/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.2935 - accuracy: 0.9182
# Epoch 19/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.2383 - accuracy: 0.9636
# Epoch 20/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.2327 - accuracy: 0.9364
# Epoch 21/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1893 - accuracy: 0.9455
# Epoch 22/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1387 - accuracy: 0.9727
# Epoch 23/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.1403 - accuracy: 0.9636
# Epoch 24/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.2401 - accuracy: 0.9364
# Epoch 25/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.2149 - accuracy: 0.9455
# Epoch 26/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.1550 - accuracy: 0.9818
# Epoch 27/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0833 - accuracy: 0.9818
# Epoch 28/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1021 - accuracy: 0.9909
# Epoch 29/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.1072 - accuracy: 0.9818
# Epoch 30/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.0901 - accuracy: 0.9818
# Epoch 31/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0791 - accuracy: 0.9818
# Epoch 32/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.1296 - accuracy: 0.9818
# Epoch 33/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.1009 - accuracy: 0.9818
# Epoch 34/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1120 - accuracy: 0.9636
# Epoch 35/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0897 - accuracy: 0.9818
# Epoch 36/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0532 - accuracy: 1.0000
# Epoch 37/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.0528 - accuracy: 1.0000
# Epoch 38/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0400 - accuracy: 1.0000
# Epoch 39/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0614 - accuracy: 0.9909
# Epoch 40/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0603 - accuracy: 1.0000
# Epoch 41/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0854 - accuracy: 0.9909
# Epoch 42/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.1004 - accuracy: 0.9636
# Epoch 43/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0698 - accuracy: 0.9818
# Epoch 44/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0721 - accuracy: 0.9727
# Epoch 45/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.0583 - accuracy: 0.9909
# Epoch 46/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 47/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.0342 - accuracy: 1.0000
# Epoch 48/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0987 - accuracy: 0.9636
# Epoch 49/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 50/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0609 - accuracy: 0.9818
# Epoch 51/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.0701 - accuracy: 0.9909
# Epoch 52/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0387 - accuracy: 0.9909
# Epoch 53/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.0404 - accuracy: 0.9909
# Epoch 54/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0545 - accuracy: 1.0000
# Epoch 55/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 56/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 57/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.0388 - accuracy: 0.9909
# Epoch 58/200
# 22/22 [==============================] - 0s 999us/step - loss: 0.0749 - accuracy: 0.9909
# Epoch 59/200
# 22/22 [==============================] - 0s 909us/step - loss: 0.0322 - accuracy: 1.0000
# Epoch 60/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 61/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0404 - accuracy: 0.9909
# Epoch 62/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 63/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0364 - accuracy: 0.9909
# Epoch 64/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0447 - accuracy: 0.9909
# Epoch 65/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0389 - accuracy: 0.9909
# Epoch 66/200
# 22/22 [==============================] - 0s 772us/step - loss: 0.0618 - accuracy: 0.9727
# Epoch 67/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0226 - accuracy: 0.9909
# Epoch 68/200
# 22/22 [==============================] - 0s 772us/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 69/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0926 - accuracy: 0.9818
# Epoch 70/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0457 - accuracy: 0.9909
# Epoch 71/200
# 22/22 [==============================] - 0s 772us/step - loss: 0.0466 - accuracy: 0.9909
# Epoch 72/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0299 - accuracy: 0.9909
# Epoch 73/200
# 22/22 [==============================] - 0s 727us/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 74/200
# 22/22 [==============================] - 0s 772us/step - loss: 0.0375 - accuracy: 0.9818
# Epoch 75/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0413 - accuracy: 0.9818
# Epoch 76/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0401 - accuracy: 0.9909
# Epoch 77/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0464 - accuracy: 0.9818
# Epoch 78/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 79/200
# 22/22 [==============================] - 0s 954us/step - loss: 0.0442 - accuracy: 0.9818
# Epoch 80/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 81/200
# 22/22 [==============================] - 0s 854us/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 82/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0345 - accuracy: 0.9818
# Epoch 83/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0308 - accuracy: 0.9818
# Epoch 84/200
# 22/22 [==============================] - 0s 727us/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 85/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0396 - accuracy: 0.9909
# Epoch 86/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 87/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 88/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0258 - accuracy: 0.9909
# Epoch 89/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 90/200
# 22/22 [==============================] - 0s 954us/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 91/200
# 22/22 [==============================] - 0s 999us/step - loss: 0.0237 - accuracy: 0.9909
# Epoch 92/200
# 22/22 [==============================] - 0s 999us/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 93/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0224 - accuracy: 0.9909
# Epoch 94/200
# 22/22 [==============================] - 0s 772us/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 95/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 96/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 97/200
# 22/22 [==============================] - 0s 909us/step - loss: 0.0148 - accuracy: 0.9909
# Epoch 98/200
# 22/22 [==============================] - 0s 909us/step - loss: 0.0341 - accuracy: 0.9909
# Epoch 99/200
# 22/22 [==============================] - 0s 772us/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 100/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 101/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 102/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 103/200
# 22/22 [==============================] - 0s 772us/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 104/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 105/200
# 22/22 [==============================] - 0s 954us/step - loss: 0.0139 - accuracy: 0.9909
# Epoch 106/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 107/200
# 22/22 [==============================] - 0s 863us/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 108/200
# 22/22 [==============================] - 0s 999us/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 109/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0329 - accuracy: 0.9909
# Epoch 110/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 111/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 112/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 113/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 114/200
# 22/22 [==============================] - 0s 999us/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 115/200
# 22/22 [==============================] - 0s 817us/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 116/200
# 22/22 [==============================] - 0s 954us/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 117/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 118/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 119/200
# 22/22 [==============================] - 0s 999us/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 120/200
# 22/22 [==============================] - 0s 999us/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 121/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0357 - accuracy: 0.9909
# Epoch 122/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0483 - accuracy: 0.9909
# Epoch 123/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0333 - accuracy: 0.9909
# Epoch 124/200
# 22/22 [==============================] - 0s 999us/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 125/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 126/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0301 - accuracy: 0.9818
# Epoch 127/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0272 - accuracy: 0.9909
# Epoch 128/200
# 22/22 [==============================] - 0s 908us/step - loss: 0.0355 - accuracy: 0.9818
# Epoch 129/200
# 22/22 [==============================] - 0s 909us/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 130/200
# 22/22 [==============================] - 0s 954us/step - loss: 0.0619 - accuracy: 0.9727
# Epoch 131/200
# 22/22 [==============================] - 0s 727us/step - loss: 0.0298 - accuracy: 0.9909
# Epoch 132/200
# 22/22 [==============================] - 0s 772us/step - loss: 0.0326 - accuracy: 0.9909
# Epoch 133/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 134/200
# 22/22 [==============================] - 0s 999us/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 135/200
# 22/22 [==============================] - 0s 954us/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 136/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 137/200
# 22/22 [==============================] - 0s 999us/step - loss: 0.0208 - accuracy: 0.9909
# Epoch 138/200
# 22/22 [==============================] - 0s 999us/step - loss: 0.0171 - accuracy: 0.9909
# Epoch 139/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 140/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 141/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 142/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0190 - accuracy: 0.9909
# Epoch 143/200
# 22/22 [==============================] - 0s 772us/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 144/200
# 22/22 [==============================] - 0s 999us/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 145/200
# 22/22 [==============================] - ETA: 0s - loss: 0.0604 - accuracy: 1.00 - 0s 1ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 146/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0232 - accuracy: 0.9909
# Epoch 147/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0221 - accuracy: 0.9909
# Epoch 148/200
# 22/22 [==============================] - 0s 999us/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 149/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0280 - accuracy: 0.9818
# Epoch 150/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0109 - accuracy: 0.9909
# Epoch 151/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 152/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 153/200
# 22/22 [==============================] - 0s 772us/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 154/200
# 22/22 [==============================] - 0s 772us/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 155/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 156/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0252 - accuracy: 0.9909
# Epoch 157/200
# 22/22 [==============================] - 0s 1000us/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 158/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 159/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 160/200
# 22/22 [==============================] - 0s 954us/step - loss: 0.0125 - accuracy: 0.9909
# Epoch 161/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 162/200
# 22/22 [==============================] - 0s 818us/step - loss: 0.0167 - accuracy: 0.9909
# Epoch 163/200
# 22/22 [==============================] - 0s 772us/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 164/200
# 22/22 [==============================] - 0s 727us/step - loss: 0.0154 - accuracy: 0.9909
# Epoch 165/200
# 22/22 [==============================] - 0s 999us/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 166/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 167/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 168/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 169/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 170/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0148 - accuracy: 0.9909
# Epoch 171/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 172/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 173/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 174/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0464 - accuracy: 0.9909
# Epoch 175/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 176/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0137 - accuracy: 0.9909
# Epoch 177/200
# 22/22 [==============================] - 0s 772us/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 178/200
# 22/22 [==============================] - 0s 772us/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 179/200
# 22/22 [==============================] - 0s 772us/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 180/200
# 22/22 [==============================] - 0s 909us/step - loss: 0.0321 - accuracy: 0.9909
# Epoch 181/200
# 22/22 [==============================] - 0s 954us/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 182/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 183/200
# 22/22 [==============================] - 0s 954us/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 184/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 185/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 186/200
# 22/22 [==============================] - 0s 999us/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 187/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 188/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 189/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 190/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 191/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 192/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 193/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0162 - accuracy: 0.9909
# Epoch 194/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 195/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 196/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 197/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 198/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 199/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 200/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0113 - accuracy: 1.0000
# model is created

# %% [markdown]
# we can also check the model summary to see how many parameters were trained

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 200)               22600
# _________________________________________________________________
# dropout (Dropout)            (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 13)                1313
# =================================================================
# Total params: 44,013
# Trainable params: 44,013
# Non-trainable params: 0
# _________________________________________________________________

# %%
#pip install tf-nightly

# %% [markdown]
# In this step we load the model trained and created previously, as well as the intents file, the words and classes file

# %%
model = load_model('chatbot_model.h5')
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %% [markdown]
# Here we create the functions pipeline for the chatbot activity:
#     1. sentences inputted by the user are cleaned up, tokenized, reduced to base form
#     2. cleaned sentences are turned into bag of words
#     3. based on the bag of words a function is predicting in which of the 13 classes the user sentence needs to be placed
#     4. another function is creating a randomization of retrieving one of the response answers based on the tags
#     5. last function is making the connection between the user input and the answer the chatbot retrieves

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - splitting words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stemming every word - reducing to base form
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for words that exist in sentence
def bag_of_words(sentence, words, show_details=True):
    # tokenizing patterns
    sentence_words = clean_up_sentence(sentence)
    # bag of words - vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,word in enumerate(words):
            if word == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % word)
    return(np.array(bag))
def predict_class(sentence):
    # filter below  threshold predictions
    p = bag_of_words(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sorting strength probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result
def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %% [markdown]
# This last step is simply to create the interface for interaction with the chatbot in a nice environment

# %%
#Creating tkinter GUI
import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    if msg != '':
        ChatBox.config(state=NORMAL)
        ChatBox.insert(END, "You: " + msg + '\n\n')
        ChatBox.config(foreground="#446665", font=("Verdana", 12 )) 
        ints = predict_class(msg)
        res = getResponse(ints, intents)
        ChatBox.insert(END, "Fin: " + res + '\n\n')           
        ChatBox.config(state=DISABLED)
        ChatBox.yview(END)

root = Tk()
root.title("Fin the Finance Assistance Chatbot")
root.geometry("400x500")
root.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatBox = Text(root, bd=0, bg="white", height="8", width="60", font="Arial",)
ChatBox.config(state=DISABLED)

#Bind scrollbar to Chat window

scrollbar = Scrollbar(root, command=ChatBox.yview, cursor="double_arrow")
ChatBox['yscrollcommand'] = scrollbar.set

#Create Button to send message

SendButton = Button(root, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#f9a602", activebackground="#3c9d9b",fg='#000000',
                    command= send )

#Create the box to enter message

EntryBox = Text(root, bd=0, bg="white",width="29", height="5", font="Arial")

#EntryBox.bind("<Return>", send)

#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatBox.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)
root.mainloop()

# %%
#python train_chatbot.py

# %%
#python chatgui.py

# %% [markdown]
# ### The final step is to test the accuracy of the answers given by the chatbot.

# %% [markdown]
# #### With a score of 9 correct answers from 12 questions (Sample as below), we can consider this a fairly reliable chatbot for the task. We need to further test it with additional users and additional scenarios

# %% [markdown]
# You: hei good evening
#
# Correct Fin: Hi, I am Fin, your Finance assistant chatbot, how can I help you today?
#
# You: lets see if you can help as my invoice is incorrect
#
# Correct Fin: I am sorry you consider your invoice to be incorrect. Can you let me know which of these areas is incorrect:Wrong amount/Wrong Billing Details/Wrong Due Date)
#
# You: the amount on the invoice is wrong
#
# Correct Fin: It seems you think the amount of the invoice is wrong. Please mention the invoice number, amount you think should have been charged and the reason why and I will open a case for our Finance Department to come back to you in the shortest time)
#
# You: ok this is great thank you have a nice day
#
# Correct Fin: Have a nice day! Before you go, do not forget to check the details for the recommended automated payment methods (link)
#
# You: there is something else. i need to know what are my payment options
#
# Wrong Fin: The available payment methods are credit card, bank transfer and automated payment. You can change your payment method here ...
#
# You: perfect this helps
#
# Wrong Fin: Yes please tell me your problem so I can assist you
#
# You: i do not need any other support. thank you very much
#
# Wrong Fin: Yes please tell me your problem so I can assist you
#
# You: thank you! have a great day
#
# Correct Fin: Have a nice day! Before you go, do not forget to check the details for the recommended automated payment methods (link)
#
# You: where can i retrieve a copy of my invoice
#
# Correct Fin: You can find a copy of your invoice by accessing this path ...
#
# You: and how can i pay this invoice
#
# Correct Fin: The available payment methods are credit card, bank transfer and automated payment. You can process payments from here ...
#
# You: aha and what if i want to change the payment method?
#
# Correct Fin: The available payment methods are credit card, bank transfer and automated payment. You can change your payment method here ...
#
# You: this is helpful thanks
#
# Correct Fin: Great to hear I could be of help! Before you go, do not forget to check the details for the recommended automated payment methods (link)

# %% [markdown]
# #### Another scenario tested is when certain words are mispelled
